# %%
from pylab import *
from numpy import outer
rc('text', usetex=False)
a=outer(arange(0,1,0.01),ones(10))
figure(figsize=(10,5))
subplots_adjust(top=0.8,bottom=0.05,left=0.01,right=0.99)
maps=[m for m in cm.datad if not m.endswith("_r")]
maps.sort()
l=len(maps)+1
for i, m in enumerate(maps):
    print maps[i]
    subplot(1,l,i+1)
    axis("off")
    imshow(a,aspect='auto',cmap=get_cmap(m),origin="lower")
    title(m,rotation=90,fontsize=10)
#    savefig("colormaps.png",dpi=100,facecolor='gray')
# Out:
# Accent
# Blues
# BrBG
# BuGn
# BuPu
# CMRmap
# Dark2
# GnBu
# Greens
# Greys
# OrRd
# Oranges
# PRGn
# Paired
# Pastel1
# Pastel2
# PiYG
# PuBu
# PuBuGn
# PuOr
# PuRd
# Purples
# RdBu
# RdGy
# RdPu
# RdYlBu
# RdYlGn
# Reds
# Set1
# Set2
# Set3
# Spectral
# YlGn
# YlGnBu
# YlOrBr
# YlOrRd
# afmhot
# autumn
# binary
# bone
# brg
# bwr
# cool
# coolwarm
# copper
# cubehelix
# flag
# gist_earth
# gist_gray
# gist_heat
# gist_ncar
# gist_rainbow
# gist_stern
# gist_yarg
# gnuplot
# gnuplot2
# gray
# hot
# hsv
# jet
# nipy_spectral
# ocean
# pink
# prism
# rainbow
# seismic
# spectral
# spring
# summer
# terrain
# winter

# %%
from mpl_toolkits.basemap import cm as bmcm

# %%
a=outer(arange(0,1,0.01),ones(10))
figure(figsize=(10,5))
subplots_adjust(top=0.8,bottom=0.05,left=0.01,right=0.99)
maps=[m for m in bmcm.datad if not m.endswith("_r")]
maps.sort()
l=len(maps)+1
for i, m in enumerate(maps):
    subplot(1,l,i+1)
    axis("off")
    print maps[i]
    instance = getattr(bmcm,maps[i])
    imshow(a,aspect='auto',cmap=instance,origin="lower")
    title(m,rotation=90,fontsize=10)
# Out:
# GMT_drywet
# GMT_gebco
# GMT_globe
# GMT_haxby
# GMT_no_green
# GMT_ocean
# GMT_polar
# GMT_red2green
# GMT_relief
# GMT_seis
# GMT_split
# GMT_wysiwyg
# StepSeq
# s3pcpn
# s3pcpn_l
# sstanom

# %%
from plotting.colormaps import cm as ocncm

# %%
a=outer(arange(0,1,0.01),ones(10))
figure(figsize=(10,5))
subplots_adjust(top=0.8,bottom=0.05,left=0.01,right=0.99)
maps=[m for m in ocncm if not m.endswith("_r")]
maps.sort()
l=len(maps)+1
for i, m in enumerate(maps):
    subplot(1,l,i+1)
    axis("off")
    print maps[i]
    instance = getattr(ocncm,maps[i])
    imshow(a,aspect='auto',cmap=instance,origin="lower")
    title(m,rotation=90,fontsize=10)
# Out:
# avhrr
# cbathy
# coolavhrrmap
# ctopo
# ctopo_pos_neg
# odv
# phasemap
# redblue_dark
# redblue_light
# redgreen
# rscolmap
# zebra
